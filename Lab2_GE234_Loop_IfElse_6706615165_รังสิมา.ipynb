# %% [markdown]
# <a href="https://colab.research.google.com/github/Rangsima-Khiaorai/GE234-Basic-Programming/blob/main/Lab2_GE234_Loop_IfElse_6706615165_%E0%B8%A3%E0%B8%B1%E0%B8%87%E0%B8%AA%E0%B8%B4%E0%B8%A1%E0%B8%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛰️ Lab 2: การใช้งาน Loop และ If-Else
# ## วิชา GE 234 Basic Programming for Geographers
#
# ### 🎯 **วัตถุประสงค์**
# 1. เข้าใจโครงสร้างการควบคุมแบบ **Loop** (`for`, `while`) และ **เงื่อนไข** (`if-else`)
# 2. สามารถใช้ `for` และ `while` loop เพื่อประมวลผลข้อมูลซ้ำ ๆ ได้
# 3. ใช้ `if-else` เพื่อกำหนดเงื่อนไขในการตัดสินใจ
# 4. นำไปประยุกต์ใช้กับข้อมูลทางภูมิศาสตร์ เช่น การคัดกรองข้อมูลพิกัดและการวิเคราะห์ข้อมูล Raster
#
# ---
#
# ## 🔹 ตัวอย่างที่ 1: การใช้ `for loop` เพื่อแสดงค่าพิกัด

# %%
# พิกัดของสถานที่สำคัญในประเทศไทย
locations = {
    "Bangkok": (13.7563, 100.5018),
    "Chiang Mai": (18.7883, 98.9853),
    "Phuket": (7.8804, 98.3923),
    "Ubon Ratchathani": (15.2287, 104.8564)
}

# วนลูปแสดงค่าพิกัด
for city, coord in locations.items():
    print(f"{city}: Latitude {coord[0]}, Longitude {coord[1]}")
# Out:
# Bangkok: Latitude 13.7563, Longitude 100.5018
# Chiang Mai: Latitude 18.7883, Longitude 98.9853
# Phuket: Latitude 7.8804, Longitude 98.3923
# Ubon Ratchathani: Latitude 15.2287, Longitude 104.8564

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 2: การใช้ `if-else` กรองข้อมูลพิกัด

# %%
for city, coord in locations.items():
    if coord[0] > 16:
        print(f"{city} อยู่ทางภาคเหนือของประเทศไทย")
    else:
        print(f"{city} ไม่ใช่จังหวัดทางภาคเหนือ")
# Out:
# Bangkok ไม่ใช่จังหวัดทางภาคเหนือ
# Chiang Mai อยู่ทางภาคเหนือของประเทศไทย
# Phuket ไม่ใช่จังหวัดทางภาคเหนือ
# Ubon Ratchathani ไม่ใช่จังหวัดทางภาคเหนือ

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 3: ใช้ `while loop` นับจำนวนจุดข้อมูล

# %%
points = [(13.7563, 100.5018), (18.7883, 98.9853), (7.8804, 98.3923)]
count = 0

while count < len(points):
    print(f"Point {count + 1}: {points[count]}")
    count += 1
# Out:
# Point 1: (13.7563, 100.5018)
# Point 2: (18.7883, 98.9853)
# Point 3: (7.8804, 98.3923)

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 4: วิเคราะห์ข้อมูล Raster ด้วย `for loop`

# %%
import numpy as np

# จำลองข้อมูล NDVI (Normalized Difference Vegetation Index)
ndvi = np.array([
    [0.2, 0.4, 0.5],
    [0.1, 0.3, 0.7],
    [0.6, 0.8, 0.2]
])

# วนลูปตรวจสอบค่าพืชพรรณ
for row in range(ndvi.shape[0]):
    for col in range(ndvi.shape[1]):
        if ndvi[row, col] > 0.3:
            print(f"พิกัด ({row}, {col}) มีพืชพรรณหนาแน่น (NDVI={ndvi[row, col]})")
# Out:
# พิกัด (0, 1) มีพืชพรรณหนาแน่น (NDVI=0.4)
# พิกัด (0, 2) มีพืชพรรณหนาแน่น (NDVI=0.5)
# พิกัด (1, 2) มีพืชพรรณหนาแน่น (NDVI=0.7)
# พิกัด (2, 0) มีพืชพรรณหนาแน่น (NDVI=0.6)
# พิกัด (2, 1) มีพืชพรรณหนาแน่น (NDVI=0.8)

# %% [markdown]
# # 📝 **กิจกรรมในแลป**
#
# 1. **แบบฝึกหัด 1**: เขียน `for loop` เพื่อแสดงชื่อจังหวัดและพิกัดจากลิสต์ของคุณเอง
# 2. **แบบฝึกหัด 2**: ใช้ `if-else` เพื่อแยกแยะพื้นที่ที่เป็นภูเขาและพื้นที่ราบจากลิสต์ของพิกัด
# 3. **แบบฝึกหัด 3**: ใช้ `while loop` เพื่อวนลูปและแสดงค่าละติจูดจากลิสต์จนกว่าจะพบค่าต่ำกว่า 10°
# 4. **แบบฝึกหัด 4**: ใช้ `for loop` วิเคราะห์ค่า NDVI และหาค่าพื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2)

# %% [markdown]
# ### 1. แบบฝึกหัด 1 : เขียน for loop เพื่อแสดงชื่อจังหวัดและพิกัดจากลิสต์ของคุณเอง

# %%
locations = {
    "Chonburi" : (13.3618, 100.9847),
    "Buriram": (14.9961, 103.1027),
    "Khon Kaen": (16.4326, 102.8252),
    "Bueng Kan": (18.3626, 103.6521),
    "Phitsanulok": (16.8187, 100.2570),
    "Lampang": (18.2926, 99.4913),
    "Chiang Rai": (19.9079, 99.8325),
    "Uthaithani": (15.3789, 100.0465),
    "Saraburi": (14.5458, 100.9103),
    "Kanchanaburi": (14.0084, 99.5015),
    "Prachuap Khiri Khan": (11.8105, 99.7909),
    "Phangnga": (8.4497, 98.5303),
    "Satun": (6.6111, 100.0631),
    "Yala": (6.5447, 101.2721)
}

for city, coord in locations.items():
    print(f"{city}: Latitude {coord[0]}, Longitude {coord[1]}")
# Out:
# Chonburi: Latitude 13.3618, Longitude 100.9847
# Buriram: Latitude 14.9961, Longitude 103.1027
# Khon Kaen: Latitude 16.4326, Longitude 102.8252
# Bueng Kan: Latitude 18.3626, Longitude 103.6521
# Phitsanulok: Latitude 16.8187, Longitude 100.257
# Lampang: Latitude 18.2926, Longitude 99.4913
# Chiang Rai: Latitude 19.9079, Longitude 99.8325
# Uthaithani: Latitude 15.3789, Longitude 100.0465
# Saraburi: Latitude 14.5458, Longitude 100.9103
# Kanchanaburi: Latitude 14.0084, Longitude 99.5015
# Prachuap Khiri Khan: Latitude 11.8105, Longitude 99.7909
# Phangnga: Latitude 8.4497, Longitude 98.5303
# Satun: Latitude 6.6111, Longitude 100.0631
# Yala: Latitude 6.5447, Longitude 101.2721

# %% [markdown]
# ### 2. แบบฝึกหัด 2 : ใช้ if-else เพื่อแยกแยะพื้นที่ที่เป็นภูเขาและพื้นที่ราบจากลิสต์ของพิกัด

# %%
for city, coord in locations.items():
    if coord[0] > 15: # Assuming latitude > 15 degrees is generally more northern/mountainous in Thailand
        print(f"{city} เป็นพื้นที่ภูเขา")
    else:
        print(f"{city} เป็นพื้นที่ราบ")
# Out:
# Chonburi เป็นพื้นที่ราบ
# Buriram เป็นพื้นที่ราบ
# Khon Kaen เป็นพื้นที่ภูเขา
# Bueng Kan เป็นพื้นที่ภูเขา
# Phitsanulok เป็นพื้นที่ภูเขา
# Lampang เป็นพื้นที่ภูเขา
# Chiang Rai เป็นพื้นที่ภูเขา
# Uthaithani เป็นพื้นที่ภูเขา
# Saraburi เป็นพื้นที่ราบ
# Kanchanaburi เป็นพื้นที่ราบ
# Prachuap Khiri Khan เป็นพื้นที่ราบ
# Phangnga เป็นพื้นที่ราบ
# Satun เป็นพื้นที่ราบ
# Yala เป็นพื้นที่ราบ

# %% [markdown]
# ### 3. แบบฝึกหัด 3 : ใช้ while loop เพื่อวนลูปและแสดงค่าละติจูดจากลิสต์จนกว่าจะพบค่าต่ำกว่า 10°

# %%
points = [(13.3618, 100.9847), (14.9961, 103.1027), (16.4326, 102.8252), (18.3626, 103.6521), (16.8187, 100.2570), (18.2926, 99.4913), (19.9079, 99.8325),
          (15.3789, 100.0465), (14.5458, 100.9103), (14.0084, 99.5015), (11.8105, 99.7909), (8.4497, 98.5303), (6.6111, 100.0631), (6.5447, 101.2721)]
count = 0

while count < len(points):
    latitude = points[count][0]
    print(f"Point {count + 1}: Latitude {latitude}")
    if latitude < 10:
        print(f"พบค่าละติจูดที่ต่ำกว่า 10 องศา ({latitude}) หยุดการทำงานของลูป")
        break
    count += 1
# Out:
# Point 1: Latitude 13.3618
# Point 2: Latitude 14.9961
# Point 3: Latitude 16.4326
# Point 4: Latitude 18.3626
# Point 5: Latitude 16.8187
# Point 6: Latitude 18.2926
# Point 7: Latitude 19.9079
# Point 8: Latitude 15.3789
# Point 9: Latitude 14.5458
# Point 10: Latitude 14.0084
# Point 11: Latitude 11.8105
# Point 12: Latitude 8.4497
# พบค่าละติจูดที่ต่ำกว่า 10 องศา (8.4497) หยุดการทำงานของลูป

# %% [markdown]
# ### 4. แบบฝึกหัด 4 : ใช้ for loop วิเคราะห์ค่า NDVI และหาค่าพื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2)

# %%
import numpy as np

# จำลองข้อมูล NDVI (Normalized Difference Vegetation Index)
ndvi = np.array([
    [0.2, 0.4, 0.5],
    [0.1, 0.3, 0.7],
    [0.6, 0.8, 0.2]
])

# วนลูปตรวจสอบค่าพืชพรรณและหาพื้นที่แห้งแล้ง
print("พื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2):")
for row in range(ndvi.shape[0]):
    for col in range(ndvi.shape[1]):
        if ndvi[row, col] < 0.2:
            print(f"พิกัด ({row}, {col}) มีค่า NDVI ต่ำ (NDVI={ndvi[row, col]}) ซึ่งบ่งชี้ถึงสภาพแห้งแล้ง")
# Out:
# พื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2):
# พิกัด (1, 0) มีค่า NDVI ต่ำ (NDVI=0.1) ซึ่งบ่งชี้ถึงสภาพแห้งแล้ง

# %% [markdown]
# จัดทำโดย : นางสาวรังสิมา เขียวร้าย 6706615165
